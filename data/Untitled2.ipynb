# %%
import pandas as pd

# %%
import requests

url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"x-rapidapi-key": "a0f2f907bdmsh78d8189a113c912p13905fjsn473319db76f9",
	"x-rapidapi-host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': None, 'country': 'Diamond-Princess', 'population': None, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 699, '1M_pop': None, 'total': 712}, 'deaths': {'new': None, '1M_pop': None, 'total': 13}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2025-02-27', 'time': '2025-02-27T12:00:08+00:00'}, {'continent': 'Europe', 'country': 'Vatican-City', 'population': 799, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 29, '1M_pop': '36295', 'total': 29}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2025-02-27', 'time': '2025-02-27T12:00:08+00:00'}, {'continent': 'Africa', 'country': 'Western-Sahara', 'population': 626161, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 9, '1M_pop': '16', 'total': 10}, 'deaths': {'new': None, '1M_pop': '2', 'total': 1}, 'tests': {'1M_pop': None, 't
# ...

# %%
country_deaths_list = []

# %%
if isinstance(data, list):  # Assuming the response is a list of dictionaries
    for record in data:
        # Check if the continent is 'Europe'
        if record.get('continent') == 'Europe':
            country_name = record.get('country', 'N/A')
            total_deaths = record.get('deaths', {}).get('total', 'N/A')
            
            # Append the country's name and its total deaths to the list
            country_deaths_list.append({'Country': country_name, 'COVID Deaths': total_deaths})

# Display the first 10 countries with their respective COVID deaths
print(country_deaths_list[:10])
# Out:
# []

# %%
import requests

# Replace with your actual API URL and API key
url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"x-rapidapi-key": "a0f2f907bdmsh78d8189a113c912p13905fjsn473319db76f9",
	"x-rapidapi-host": "covid-193.p.rapidapi.com"
}

# Fetch data from the API
response = requests.get(url, headers=headers)

# Check if the response was successful
if response.status_code == 200:
    data = response.json()  # Parse JSON data
else:
    print(f"Failed to retrieve data: {response.status_code}")
    data = {}

# Step 1: Print out the first few records to inspect the response structure
print("First 3 records in the API response:")
print(data[:3])  # Print the first 3 items, or print the entire response if it's small
# Out:
# First 3 records in the API response:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 23
#      21 # Step 1: Print out the first few records to inspect the response structure
#      22 print("First 3 records in the API response:")
# ---> 23 print(data[:3])
#
# KeyError: slice(None, 3, None)

# %%
type(response.json())
# Out:
# dict

# %%
# Step 1: Print the keys of the dictionary to inspect its structure
print(f"Keys in the response dictionary: {data.keys()}")
# Out:
# Keys in the response dictionary: dict_keys(['get', 'parameters', 'errors', 'results', 'response'])

# %%
# Print the entire API response to understand its structure
print(f"Full response data: {data}")


# Print out the first few records from 'results' to inspect its structure
print(f"First 3 entries in 'results': {results[:3]}")
# Out:
# Full response data: {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': 'Africa', 'country': 'Saint-Helena', 'population': 6115, 'cases': {'new': None, 'active': 2164, 'critical': None, 'recovered': 2, '1M_pop': '354211', 'total': 2166}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2025-02-27', 'time': '2025-02-27T12:30:08+00:00'}, {'continent': 'South-America', 'country': 'Falkland-Islands', 'population': 3539, 'cases': {'new': None, 'active': 0, 'critical': None, 'recovered': 1930, '1M_pop': '545352', 'total': 1930}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': '2439107', 'total': 8632}, 'day': '2025-02-27', 'time': '2025-02-27T12:30:08+00:00'}, {'continent': 'North-America', 'country': 'Montserrat', 'population': 4965, 'cases': {'new': None, 'active': 19, 'critical': None, 'recovered': 1376, '1M_pop': '282578', 'total': 1403}, 'deaths': {'new': N
# ...

# %%
# Check the type and contents of 'results'
results = data.get('results', None)
print(f"Type of 'results': {type(results)}")
print(f"Contents of 'results': {results}")
# Out:
# Type of 'results': <class 'int'>
# Contents of 'results': 238

# %%
# Print the first few entries of the entire response data
print(f"First 5 entries in the response: {str(data)[:500]}")  # Limiting to the first 500 characters
# Out:
# First 5 entries in the response: {'get': 'statistics', 'parameters': [], 'errors': [], 'results': 238, 'response': [{'continent': 'Africa', 'country': 'Saint-Helena', 'population': 6115, 'cases': {'new': None, 'active': 2164, 'critical': None, 'recovered': 2, '1M_pop': '354211', 'total': 2166}, 'deaths': {'new': None, '1M_pop': None, 'total': None}, 'tests': {'1M_pop': None, 'total': None}, 'day': '2025-02-27', 'time': '2025-02-27T12:30:08+00:00'}, {'continent': 'South-America', 'country': 'Falkland-Islands', 'population': 3539

# %%
# Check for errors in the response
if 'errors' in data:
    print(f"Errors in the response: {data['errors']}")
# Out:
# Errors in the response: []

# %%
response_data = data.get('response', [])

country_deaths_list = []

for record in response_data:
    if record.get('continent') == 'Europe':
        country_name = record.get('country', 'N/A')
        total_deaths = record.get('deaths', {}).get('total', 'N/A')

        country_deaths_list.append({'Country': country_name, 'COVID Deaths': total_deaths})

print(country_deaths_list[:10])
# Out:
# [{'Country': 'Vatican-City', 'COVID Deaths': None}, {'Country': 'Isle-of-Man', 'COVID Deaths': 116}, {'Country': 'Faeroe-Islands', 'COVID Deaths': 28}, {'Country': 'San-Marino', 'COVID Deaths': 128}, {'Country': 'Liechtenstein', 'COVID Deaths': 94}, {'Country': 'Gibraltar', 'COVID Deaths': 113}, {'Country': 'Monaco', 'COVID Deaths': 67}, {'Country': 'Channel-Islands', 'COVID Deaths': 228}, {'Country': 'Malta', 'COVID Deaths': 885}, {'Country': 'Andorra', 'COVID Deaths': 165}]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(european_country_deaths_list)

df['COVID Deaths'] = pd.to_numeric(df['COVID Deaths'], errors='coerce')

df = df.dropna(subset=['COVID Deaths'])

df = df.sort_values(by='COVID Deaths', ascending=False)

df.head(10)
# Out:
#     Country  COVID Deaths
# 38   Europe     2101824.0
# 43   Russia      402756.0
# 42       UK      232112.0
# 41    Italy      196487.0
# 40  Germany      183027.0
# 39   France      167642.0
# 37    Spain      121760.0
# 45   Poland      120598.0
# 36  Ukraine      112418.0
# 23  Romania       68929.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Country': ['Russia', 'UK', 'Italy', 'Germany', 'France', 'Spain', 'Poland', 'Ukraine', 'Romania'],
    'COVID Deaths': [402756.0, 232112.0, 196487.0, 183027.0, 167642.0, 121760.0, 120598.0, 112418.0, 68929.0]
}

df = pd.DataFrame(data)

df = df.sort_values(by='COVID Deaths', ascending=False)

df.head(10)
# Out:
#    Country  COVID Deaths
# 0   Russia      402756.0
# 1       UK      232112.0
# 2    Italy      196487.0
# 3  Germany      183027.0
# 4   France      167642.0
# 5    Spain      121760.0
# 6   Poland      120598.0
# 7  Ukraine      112418.0
# 8  Romania       68929.0

# %%
plt.figure(figsize=(20, 8))  
plt.barh(df['Country'], df['COVID Deaths'], color='red') 

plt.xlabel('COVID Deaths')
plt.ylabel('Country')
plt.title('Top 9 countries who suffered the most COVID deaths (Including Russia)')

plt.tight_layout()
plt.show()
