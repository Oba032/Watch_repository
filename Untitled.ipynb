# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
print(os.getcwd())
# Out:
# C:\Users\oba032\GitHub_Watch\Repository\Watch_repository

# %%
os.chdir(r"C:\Users\oba032\OneDrive - UiT Office 365\Desktop\Health Export 2\Main file - Unzipped")
print(os.getcwd())
# Out:
# C:\Users\oba032\OneDrive - UiT Office 365\Desktop\Health Export 2\Main file - Unzipped

# %%
df = pd.read_csv('Export_2.csv', sep=',')
print(df.head())
# Out:
#                        Date  Active Energy (kJ)  Apple Stand Hour (hours)  \
# 2025-02-17 00:00:00  4064.0                12.0                     110.0
# 2025-02-18 00:00:00  1747.0                10.0                      47.0
# 2025-02-19 00:00:00  2243.0                11.0                      68.0
# 2025-02-20 00:00:00  2264.0                13.0                      66.0
# 2025-02-21 00:00:00  4502.0                 8.0                     121.0
#
#                      Apple Stand Time (min)  Heart Rate [Min] (bpm)  \
# 2025-02-17 00:00:00                    47.0                   164.0
# 2025-02-18 00:00:00                    47.0                   144.0
# 2025-02-19 00:00:00                    50.0                   127.0
# 2025-02-20 00:00:00                    49.0                   147.0
# 2025-02-21 00:00:00                    51.0                   166.0
#
#                      Heart Rate [Max] (bpm)  Heart Rate [Avg] (bpm)  \
# ...
