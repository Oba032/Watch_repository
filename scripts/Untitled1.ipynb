# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\oba032\ExportV2\data

# %%
with open('Export2.csv', 'r') as file:
    for i in range(50):
        print(file.readline())
# Out:
# Date,Active Energy (kJ),Apple Move Time (min),Apple Sleeping Wrist Temperature (ÂºC),Apple Stand Hour (hours),Heart Rate [Min] (bpm),Heart Rate [Max] (bpm),Heart Rate [Avg] (bpm),Respiratory Rate (count/min),Resting Energy (kJ),Resting Heart Rate (bpm),Sleep Analysis [Asleep] (hr),Sleep Analysis [In Bed] (hr),Sleep Analysis [Core] (hr),Sleep Analysis [Deep] (hr),Sleep Analysis [REM] (hr),Sleep Analysis [Awake] (hr),Stair Speed: Down (m/s),Stair Speed: Up (m/s),Step Count (steps),Walking Heart Rate Average (bpm),Walking Speed (km/hr),Walking Step Length (cm)
#
# 2024-12-24 00:00:00,52.23,,,,61,72,68.22,,6481,,,,,,,,,,1389,,3.44,56.6,
#
# 2024-12-25 00:00:00,1540,,,12,52,110,71.82,14.48,9168,63,2.5833333333333335,0.0,3.224999999999999,0.475,0.45,0.016666666666666666,0.275,0.283,2753,91.5,3.46,58,
#
# 2024-12-26 00:00:00,3384,,,11,54,162,87.17,15.67,9117,63,0.0,0.0,5.991666666666667,0.9583333333333333,0.9833333333333334,0.7333333333333334,0.31,0.272,3290,99,3.49,58.71,
#
# ...

# %%
import pandas as pd

# Read CSV and parse the 'Date' column as dates
df = pd.read_csv('Export2.csv', sep=',', parse_dates=['Date'])

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                        Date  Active Energy (kJ)  Apple Move Time (min)  \
# 2024-12-24 00:00:00   52.23                 NaN                    NaN
# 2024-12-25 00:00:00  1540.0                 NaN                    NaN
# 2024-12-26 00:00:00  3384.0                 NaN                    NaN
# 2024-12-27 00:00:00  3786.0                 NaN                    NaN
# 2024-12-28 00:00:00  1562.0                 NaN                    NaN
#
#                      Apple Sleeping Wrist Temperature (ºC)  \
# 2024-12-24 00:00:00                                    NaN
# 2024-12-25 00:00:00                                   12.0
# 2024-12-26 00:00:00                                   11.0
# 2024-12-27 00:00:00                                   14.0
# 2024-12-28 00:00:00                                   10.0
#
#                      Apple Stand Hour (hours)  Heart Rate [Min] (bpm)  \
# 2024-12-24 00:00:00                      61.0                    72.0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# Out:
# C:\Users\oba032\AppData\Local\Temp\ipykernel_24156\2263964175.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
import pandas as pd

# Read the CSV without parse_dates
df = pd.read_csv('Export2.csv', sep=',')

# Explicitly specify the date format (adjust the format string if needed)
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                     Date  Active Energy (kJ)  Apple Move Time (min)  \
# 2024-12-24 00:00:00  NaT                 NaN                    NaN
# 2024-12-25 00:00:00  NaT                 NaN                    NaN
# 2024-12-26 00:00:00  NaT                 NaN                    NaN
# 2024-12-27 00:00:00  NaT                 NaN                    NaN
# 2024-12-28 00:00:00  NaT                 NaN                    NaN
#
#                      Apple Sleeping Wrist Temperature (ºC)  \
# 2024-12-24 00:00:00                                    NaN
# 2024-12-25 00:00:00                                   12.0
# 2024-12-26 00:00:00                                   11.0
# 2024-12-27 00:00:00                                   14.0
# 2024-12-28 00:00:00                                   10.0
#
#                      Apple Stand Hour (hours)  Heart Rate [Min] (bpm)  \
# 2024-12-24 00:00:00                      61.0                    72.0
# ...
